# %% [markdown]
# <a href="https://colab.research.google.com/github/luciedum-dot/Intro-to-data-analysis-with-Python---Final-Project/blob/main/Notebook%202%20-%20Parts%202%20and%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Part 2 : Analysing different variables - sex, age and nationality**
# In this notebook, we will look at the profile of the MEC and analyse 3 different variables for different types of offense

# %% [markdown]
# #1.Preliminatory work
# This section repeats work used for the Notebook 1

# %%
# !pip install pandas numpy matplotlib seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !git clone https://github.com/luciedum-dot/Intro-to-data-analysis-with-Python---Final-Project.git
# Out:
# fatal: destination path 'Intro-to-data-analysis-with-Python---Final-Project' already exists and is not an empty directory.

# %% [markdown]
# ##1.1 Read and pivot Excel File - MEC

# %%
#Read Excel File - total accused people and display the sheets' names

path = "Intro-to-data-analysis-with-Python---Final-Project/Data/mec.xlsx"

xls = pd.ExcelFile(path)
xls.sheet_names
# Out:
# ['Lisez moi',
#  '1.sexe - age',
#  '2.nationalité',
#  '3.sexe',
#  '4.nationalité majmin',
#  '5.PM - PP']

# %%
#Show the Excel File on the sheet sex, in order to look at the "total" line for every year and see the trend

#Read Excel on the sheet 3.sexe, skipping the first 2 rows and setting multiple headers (years and categories)
df = pd.read_excel(path, sheet_name="3.sexe", skiprows=2, header=[0, 1])

#Remove the 1st empty column of the sheet
df = df.iloc[:,1:]

#Pivot the year header
pivoted_df = (
    df
    .set_index("Sexe")
    .stack(level=1, future_stack=True)          # move second header to rows & future_stack=True just allow us to avoid a warning
    .reset_index()           # make it a column
    .rename(columns={"level_1": "Année"})
  )

#Cast the type of Sexe column from tupple to string
pivoted_df["Sexe"] = pivoted_df["Sexe"].str[0]

pivoted_df.head(30)
# Out:
#      Sexe  Année  \
# 0   Femme   2016
# 1   Femme   2017
# 2   Femme   2018
# 3   Femme   2019
# 4   Femme   2020
# 5   Femme   2021
# 6   Femme   2022
# 7   Femme   2023
# 8   Femme   2024
# 9   Homme   2016
# 10  Homme   2017
# 11  Homme   2018
# 12  Homme   2019
# 13  Homme   2020
# 14  Homme   2021
# 15  Homme   2022
# 16  Homme   2023
# 17  Homme   2024
# 18  Total   2016
# 19  Total   2017
# 20  Total   2018
# 21  Total   2019
# 22  Total   2020
# 23  Total   2021
# 24  Total   2022
# 25  Total   2023
# 26  Total   2024
#
#     Homicides (y compris coups et blessures volontaires suivis de mort)  \
# 0                                                 135
# 1                                                 174
# 2                                                 188
# 3                                                 159
# 4                                                 148
# 5                                                 163
# 6                                                 173
# 7                                                 217
# 8                                                 192
# 9                                                 851
# 10                                                950
# 11                                               1014
# 12                                                965
# 13                                                928
# 14                                               1012
# 15                                               1185
# 16                                               1210
# 17                                               1256
# 18                                                986
# 19                                               1124
# 20                                               1202
# 21                                               1124
# 22                                               1076
# 23                                               1175
# 24                                               1358
# 25                                               1427
# 26                                               1448
#
#     Tentatives d'homicide  Violences physiques dans le cadre intra-familial  \
# 0                     195                                             15202
# 1                     196                                             16166
# 2                     197                                             16964
# 3                     209                                             19064
# 4                     254                                             22112
# 5                     258                                             27604
# 6                     294                                             32347
# 7                     347                                             38058
# 8                     345                                             41543
# 9                    1676                                             81190
# 10                   1966                                             83068
# 11                   2121                                             89938
# 12                   2184                                            101886
# 13                   2355                                            115914
# 14                   2544                                            136652
# 15                   2805                                            147710
# 16                   3115                                            156942
# 17                   3045                                            156411
# 18                   1871                                             96392
# 19                   2162                                             99234
# 20                   2318                                            106902
# 21                   2393                                            120950
# 22                   2609                                            138026
# 23                   2802                                            164256
# 24                   3099                                            180057
# 25                   3462                                            195000
# 26                   3390                                            197954
#
#     Violences physiques hors cadre intra-familial  Violences sexuelles  \
# 0                                           21601                 1735
# 1                                           22340                 1744
# 2                                           23212                 2226
# 3                                           22809                 2166
# 4                                           20139                 2367
# 5                                           21514                 2731
# 6                                           21104                 2846
# 7                                           22519                 3154
# 8                                           22977                 3642
# 9                                          105280                36515
# 10                                         108123                39451
# 11                                         117296                45254
# 12                                         113814                48924
# 13                                         106081                50138
# 14                                         111681                62749
# 15                                         110084                67452
# 16                                         115021                73395
# 17                                         113430                77274
# 18                                         126881                38250
# 19                                         130463                41195
# 20                                         140508                47480
# 21                                         136623                51090
# 22                                         126220                52505
# 23                                         133195                65480
# 24                                         131188                70298
# 25                                         137540                76549
# 26                                         136407                80916
#
#     Viols et tentatives de viols  Vols avec arme  Vols violents sans arme  \
# 0                            179             257                     1574
# 1                            157             285                     1398
# 2                            212             235                     1389
# 3                            264             239                     1224
# 4                            329             240                     1137
# 5                            419             216                      982
# 6                            524             213                      970
# 7                            644             253                     1095
# 8                            739             273                      905
# 9                          10502            5474                    17477
# 10                         11612            5689                    16046
# 11                         13506            5380                    16373
# 12                         15024            5187                    16426
# 13                         16487            4808                    15120
# 14                         22111            4721                    15150
# 15                         24754            4790                    13535
# 16                         27598            4827                    12715
# 17                         28296            4797                    11904
# 18                         10681            5731                    19051
# 19                         11769            5974                    17444
# 20                         13718            5615                    17762
# 21                         15288            5426                    17650
# 22                         16816            5048                    16257
# 23                         22530            4937                    16132
# 24                         25278            5003                    14505
# 25                         28242            5080                    13810
# 26                         29035            5070                    12809
#
#     Vols sans violence contre des personnes  Cambriolages de logement  \
# 0                                     16709                      2953
# 1                                     16490                      2898
# 2                                     16756                      3021
# 3                                     16352                      3458
# 4                                     13291                      2548
# 5                                     14264                      2396
# 6                                     12799                      2549
# 7                                     13423                      2853
# 8                                     12694                      2729
# 9                                     56807                     39796
# 10                                    59019                     40099
# 11                                    60923                     41299
# 12                                    60228                     37067
# 13                                    52007                     32586
# 14                                    51846                     29884
# 15                                    51986                     28591
# 16                                    52229                     30124
# 17                                    50564                     29358
# 18                                    73516                     42749
# 19                                    75509                     42997
# 20                                    77679                     44320
# 21                                    76580                     40525
# 22                                    65298                     35134
# 23                                    66110                     32280
# 24                                    64785                     31140
# 25                                    65652                     32977
# 26                                    63258                     32087
#
#     Vols de véhicule  Vols dans les véhicule  \
# 0                991                    1018
# 1                959                    1437
# 2               1087                    1303
# 3                875                     934
# 4                892                     964
# 5                983                    1181
# 6                975                    1040
# 7               1285                     841
# 8               1257                     957
# 9              25072                   24294
# 10             22661                   25815
# 11             24482                   27004
# 12             21742                   24546
# 13             19633                   22786
# 14             19704                   21594
# 15             18608                   22372
# 16             22127                   20521
# 17             22668                   23136
# 18             26063                   25312
# 19             23620                   27252
# 20             25569                   28307
# 21             22617                   25480
# 22             20525                   23750
# 23             20687                   22775
# 24             19583                   23412
# 25             23412                   21362
# 26             23925                   24093
#
#     Vols d'accessoires sur les véhicules  \
# 0                                    297
# 1                                    361
# 2                                    258
# 3                                    325
# 4                                    404
# 5                                    206
# 6                                    316
# 7                                    310
# 8                                    272
# 9                                   7220
# 10                                  9225
# 11                                  8383
# 12                                  7862
# 13                                  6464
# 14                                  5813
# 15                                  7515
# 16                                  7393
# 17                                  7293
# 18                                  7517
# 19                                  9586
# 20                                  8641
# 21                                  8187
# 22                                  6868
# 23                                  6019
# 24                                  7831
# 25                                  7703
# 26                                  7565
#
#     Destructions et dégradations volontaires  \
# 0                                       7981
# 1                                       8435
# 2                                       8537
# 3                                       9433
# 4                                       8740
# 5                                       8378
# 6                                       7955
# 7                                       8467
# 8                                       8665
# 9                                      70230
# 10                                     75565
# 11                                     77700
# 12                                     77509
# 13                                     70056
# 14                                     66974
# 15                                     63914
# 16                                     67227
# 17                                     62389
# 18                                     78211
# 19                                     84000
# 20                                     86237
# 21                                     86942
# 22                                     78796
# 23                                     75352
# 24                                     71869
# 25                                     75694
# 26                                     71054
#
#     Escroqueries et fraudes aux moyens de paiements  Trafic de stupéfiants  \
# 0                                             20123                   3489
# 1                                             19650                   3693
# 2                                             19190                   3996
# 3                                             17646                   4275
# 4                                             15767                   3680
# 5                                             16538                   4015
# 6                                             13251                   4293
# 7                                             13499                   4397
# 8                                             12668                   5090
# 9                                             43860                  37230
# 10                                            44748                  40283
# 11                                            41816                  41480
# 12                                            42977                  42784
# 13                                            36879                  37517
# 14                                            39326                  42697
# 15                                            37680                  44719
# 16                                            36723                  44393
# 17                                            34812                  47235
# 18                                            63983                  40719
# 19                                            64398                  43976
# 20                                            61006                  45476
# 21                                            60623                  47059
# 22                                            52646                  41197
# 23                                            55864                  46712
# 24                                            50931                  49012
# 25                                            50222                  48790
# 26                                            47480                  52325
#
#     Usage de stupéfiants
# 0                  16569
# 1                  17431
# 2                  17267
# 3                  16410
# 4                  14221
# 5                  17730
# 6                  19178
# 7                  21969
# 8                  21888
# 9                 165861
# 10                171371
# 11                169634
# 12                161013
# 13                146606
# 14                203642
# 15                232451
# 16                240902
# 17                268744
# 18                182430
# 19                188802
# 20                186901
# 21                177423
# 22                160827
# 23                221372
# 24                251629
# 25                262871
# 26                290632

# %% [markdown]
# ##1.2 Display the df-mec just for Sex=Total

# %%
#Visualize just the total column
#An other way to do it, but less reliable :df_total = pivoted_df.loc[18:26] #df_total.head(10)
df_total = pivoted_df[pivoted_df["Sexe"] == "Total"]
display(df_total)
# Out:
#      Sexe  Année  \
# 18  Total   2016
# 19  Total   2017
# 20  Total   2018
# 21  Total   2019
# 22  Total   2020
# 23  Total   2021
# 24  Total   2022
# 25  Total   2023
# 26  Total   2024
#
#     Homicides (y compris coups et blessures volontaires suivis de mort)  \
# 18                                                986
# 19                                               1124
# 20                                               1202
# 21                                               1124
# 22                                               1076
# 23                                               1175
# 24                                               1358
# 25                                               1427
# 26                                               1448
#
#     Tentatives d'homicide  Violences physiques dans le cadre intra-familial  \
# 18                   1871                                             96392
# 19                   2162                                             99234
# 20                   2318                                            106902
# 21                   2393                                            120950
# 22                   2609                                            138026
# 23                   2802                                            164256
# 24                   3099                                            180057
# 25                   3462                                            195000
# 26                   3390                                            197954
#
#     Violences physiques hors cadre intra-familial  Violences sexuelles  \
# 18                                         126881                38250
# 19                                         130463                41195
# 20                                         140508                47480
# 21                                         136623                51090
# 22                                         126220                52505
# 23                                         133195                65480
# 24                                         131188                70298
# 25                                         137540                76549
# 26                                         136407                80916
#
#     Viols et tentatives de viols  Vols avec arme  Vols violents sans arme  \
# 18                         10681            5731                    19051
# 19                         11769            5974                    17444
# 20                         13718            5615                    17762
# 21                         15288            5426                    17650
# 22                         16816            5048                    16257
# 23                         22530            4937                    16132
# 24                         25278            5003                    14505
# 25                         28242            5080                    13810
# 26                         29035            5070                    12809
#
#     Vols sans violence contre des personnes  Cambriolages de logement  \
# 18                                    73516                     42749
# 19                                    75509                     42997
# 20                                    77679                     44320
# 21                                    76580                     40525
# 22                                    65298                     35134
# 23                                    66110                     32280
# 24                                    64785                     31140
# 25                                    65652                     32977
# 26                                    63258                     32087
#
#     Vols de véhicule  Vols dans les véhicule  \
# 18             26063                   25312
# 19             23620                   27252
# 20             25569                   28307
# 21             22617                   25480
# 22             20525                   23750
# 23             20687                   22775
# 24             19583                   23412
# 25             23412                   21362
# 26             23925                   24093
#
#     Vols d'accessoires sur les véhicules  \
# 18                                  7517
# 19                                  9586
# 20                                  8641
# 21                                  8187
# 22                                  6868
# 23                                  6019
# 24                                  7831
# 25                                  7703
# 26                                  7565
#
#     Destructions et dégradations volontaires  \
# 18                                     78211
# 19                                     84000
# 20                                     86237
# 21                                     86942
# 22                                     78796
# 23                                     75352
# 24                                     71869
# 25                                     75694
# 26                                     71054
#
#     Escroqueries et fraudes aux moyens de paiements  Trafic de stupéfiants  \
# 18                                            63983                  40719
# 19                                            64398                  43976
# 20                                            61006                  45476
# 21                                            60623                  47059
# 22                                            52646                  41197
# 23                                            55864                  46712
# 24                                            50931                  49012
# 25                                            50222                  48790
# 26                                            47480                  52325
#
#     Usage de stupéfiants
# 18                182430
# 19                188802
# 20                186901
# 21                177423
# 22                160827
# 23                221372
# 24                251629
# 25                262871
# 26                290632

# %% [markdown]
# ##1.3 Read Population Excel

# %%
#Analyze the evolution of criminality with taking into account population growth:
path = "Intro-to-data-analysis-with-Python---Final-Project/Data/pop.xlsx"

xls_pop = pd.ExcelFile(path)
xls_pop.sheet_names
# Out:
# ['France - Figure 1',
#  'France - Figure 2',
#  'France - Figure 3',
#  'France - Figure 4',
#  'France - Figure 5',
#  'France - Figure 6',
#  'UE - Figure 1',
#  'UE - Figure 2',
#  'UE - Figure 3']

# %%
#Show the Excel File on the sheet France - Figure 2, in order to look at the "Ensemble" column for every year between 2016 to 2024
df_pop = pd.read_excel(path, sheet_name="France - Figure 2", skiprows=3)
df_pop = df_pop[0:-4] #Remove the last 4 rows which contained strings
df_pop.head(10)
# Out:
#   Année     Femmes     Hommes   Ensemble
# 0  2025  35326.405  33279.211  68605.616
# 1  2024  35254.976  33181.640  68436.616
# 2  2023  35172.311  33073.771  68246.082
# 3  2022  35092.520  32967.687  68060.207
# 4  2021  34930.005  32767.086  67697.091
# 5  2020  34812.046  32629.804  67441.850
# 6  2019  34722.069  32535.913  67257.982
# 7  2018  34594.401  32397.758  66992.159
# 8  2017  34477.222  32297.260  66774.482
# 9  2016  34372.558  32230.087  66602.645

# %%
df_pop_années = df_pop.loc[1:9]
display(df_pop_années)
# Out:
#   Année     Femmes     Hommes   Ensemble
# 1  2024  35254.976  33181.640  68436.616
# 2  2023  35172.311  33073.771  68246.082
# 3  2022  35092.520  32967.687  68060.207
# 4  2021  34930.005  32767.086  67697.091
# 5  2020  34812.046  32629.804  67441.850
# 6  2019  34722.069  32535.913  67257.982
# 7  2018  34594.401  32397.758  66992.159
# 8  2017  34477.222  32297.260  66774.482
# 9  2016  34372.558  32230.087  66602.645

# %%
df_pop_années_ensemble = df_pop_années[['Année', 'Ensemble']]

# %% [markdown]
# #2.What variables are most closely linked to committing a crime?

# %% [markdown]
# ## 2.1 Sex

# %%
#Reshaping the population data in long format (vs. wide format, where each category is in a separate column),
#so that each variable is in a single column, and there’s a column that indicates the category:
df_pop_années_long = df_pop_années.melt(
    id_vars='Année',
    value_vars=['Femmes', 'Hommes', 'Ensemble'],
    var_name='Sexe',
    value_name='Population'
)
df_pop_années_long.head()
# Out:
#   Année    Sexe  Population
# 0  2024  Femmes   35254.976
# 1  2023  Femmes   35172.311
# 2  2022  Femmes   35092.520
# 3  2021  Femmes   34930.005
# 4  2020  Femmes   34812.046

# %%
#Mapping the different sex so that the slight variations in the different df do not affect the implementation of the code

sex_mapping = {
    'Femmes': 'female',
    'Femme': 'female',
    'Hommes': 'male',
    'Homme': 'male',
    'Ensemble': 'total',
    'Total': 'total'
    }

# %%
#Safety step: inspection code to check which values exist in the Sexe column in two different DataFrames (including NaN):

print(df_pop_années_long['Sexe'].value_counts(dropna=False))
print(pivoted_df['Sexe'].value_counts(dropna=False))
# Out:
# Sexe
# Femmes      9
# Hommes      9
# Ensemble    9
# Name: count, dtype: int64
# Sexe
# Femme    9
# Homme    9
# Total    9
# Name: count, dtype: int64

# %%
#Copy created to not have to go on the top of the page to run the pivoted_df cell
pivoted_df_copy = pivoted_df.copy()

# %%
#Standardization of the values in the Sexe column using the precedently created mapping dictionary:

df_pop_années_long['Sexe'] = df_pop_années_long['Sexe'].map(sex_mapping)

pivoted_df_copy['Sexe'] = pivoted_df_copy['Sexe'].map(sex_mapping)

# %% [markdown]
# ###Sexual violences rate per 100k by sex

# %%
#Computation of the totals (whole period) by sex (Sexe) from the two different DataFrames, on the variable violences sexuelles and on the variable population

sv_totals = (
    pivoted_df_copy
    .groupby('Sexe')['Violences sexuelles']
    .sum()
    .reset_index()
)

pop_totals = (
    df_pop_années_long
    .groupby('Sexe')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by sex for 100 000 individuals:

df_sv_rates_by_sex = pd.merge(sv_totals, pop_totals, on='Sexe')

df_sv_rates_by_sex['Rate per 100k'] = (
    df_sv_rates_by_sex['Violences sexuelles'] / (df_sv_rates_by_sex['Population']*1000) * 100_000
)
df_sv_rates_by_sex_renamed = df_sv_rates_by_sex.rename(columns={
    "Violences sexuelles": "Sexual violences",
    "Sexe": "Sex"
    })
df_sv_rates_by_sex_renamed
# Out:
#       Sex  Sexual violences  Population  Rate per 100k
# 0  female             22611  313428.108       7.214095
# 1    male            501152  294081.006     170.412910
# 2   total            523763  607509.114      86.214838

# %%
#Plot barplots for different crime on the sex variable to see the criminality rate by sex,
# and then analyze for exemple which crimes women are the most likely to commit

plt.figure(figsize=(7,5))
plt.bar(df_sv_rates_by_sex_renamed["Sex"], df_sv_rates_by_sex_renamed["Rate per 100k"], color='skyblue', label='Sexual violences')
plt.title("Average sexual violence rate by sex (2016–2024)")
plt.xlabel("Sex")
plt.ylabel("Average rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ###Homicides rate by sex

# %%
#Computation of the totals by sex (Sexe) from the two different DataFrames, on the variable Homicides and on the variable population

hom_totals = (
    pivoted_df_copy
    .groupby('Sexe')['Homicides (y compris coups et blessures volontaires suivis de mort)']
    .sum()
    .reset_index()
)

pop_totals = (
    df_pop_années_long
    .groupby('Sexe')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by 100 000 individuals:

df_hom_rates_by_sex = pd.merge(hom_totals, pop_totals, on='Sexe')

df_hom_rates_by_sex['Rate per 100k'] = (
    df_hom_rates_by_sex['Homicides (y compris coups et blessures volontaires suivis de mort)'] / (df_hom_rates_by_sex['Population']*1000) * 100_000
)
df_hom_rates_by_sex_renamed = df_hom_rates_by_sex.rename(columns={
    "Homicides (y compris coups et blessures volontaires suivis de mort)": "Homicides",
    "Sexe": "Sex"
    })
df_hom_rates_by_sex_renamed
# Out:
#       Sex  Homicides  Population  Rate per 100k
# 0  female       1549  313428.108       0.494212
# 1    male       9371  294081.006       3.186537
# 2   total      10920  607509.114       1.797504

# %%
#Plot barplots for different crime on the sex variable to see the criminality rate by sex,
# and then analyze for exemple which crimes women are the most likely to commit

plt.figure(figsize=(7,5))
plt.bar(df_hom_rates_by_sex_renamed["Sex"], df_hom_rates_by_sex_renamed["Rate per 100k"], color='skyblue', label='Homicides')
plt.title("Average homicides MEC rate by sex (2016–2024)")
plt.xlabel("Sex")
plt.ylabel("Average MEC rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ###Non-violent theft rate by sex

# %%
#Computation of the totals by sex (Sexe) from the two different DataFrames, on the variable Non-violent theft and on the variable population

nvt_totals = (
    pivoted_df_copy
    .groupby('Sexe')['Vols sans violence contre des personnes']
    .sum()
    .reset_index()
)

pop_totals = (
    df_pop_années_long
    .groupby('Sexe')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by 100 000 individuals:

df_nvt_rates_by_sex = pd.merge(nvt_totals, pop_totals, on='Sexe')

df_nvt_rates_by_sex['Rate per 100k'] = (
    df_nvt_rates_by_sex['Vols sans violence contre des personnes'] / (df_nvt_rates_by_sex['Population']*1000) * 100_000
)
df_nvt_rates_by_sex_renamed = df_nvt_rates_by_sex.rename(columns={
    "Vols sans violence contre des personnes": "Non-violent theft",
    "Sexe": "Sex"
    })
df_nvt_rates_by_sex_renamed
# Out:
#       Sex  Non-violent theft  Population  Rate per 100k
# 0  female             132778  313428.108      42.363144
# 1    male             495609  294081.006     168.528055
# 2   total             628387  607509.114     103.436637

# %%
#Plot barplots for different crime on the sex variable to see the criminality rate by sex,
# and then analyze for exemple which crimes women are the most likely to commit

plt.figure(figsize=(7,5))
plt.bar(df_nvt_rates_by_sex_renamed["Sex"], df_nvt_rates_by_sex_renamed["Rate per 100k"], color='skyblue', label='Non-violent theft')
plt.title("Average MEC non-violent theft rate by sex (2016–2024)")
plt.xlabel("Sex")
plt.ylabel("Average MEC rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ###Physical domestic violence

# %%
#Computation of the totals by sex (Sexe) from the two different DataFrames, on the variable physical domestic violence and on the variable population

pdv_totals = (
    pivoted_df_copy
    .groupby('Sexe')['Violences physiques dans le cadre intra-familial']
    .sum()
    .reset_index()
)

pop_totals = (
    df_pop_années_long
    .groupby('Sexe')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by 100 000 individuals:

df_pdv_rates_by_sex = pd.merge(pdv_totals, pop_totals, on='Sexe')

df_pdv_rates_by_sex['Rate per 100k'] = (
    df_pdv_rates_by_sex['Violences physiques dans le cadre intra-familial'] / (df_pdv_rates_by_sex['Population']*1000) * 100_000
)
df_pdv_rates_by_sex_renamed = df_pdv_rates_by_sex.rename(columns={
    "Violences physiques dans le cadre intra-familial": "Physical domestic violence",
    "Sexe": "Sex"
    })
df_pdv_rates_by_sex_renamed
# Out:
#       Sex  Physical domestic violence  Population  Rate per 100k
# 0  female                      229060  313428.108      73.082150
# 1    male                     1069711  294081.006     363.747055
# 2   total                     1298771  607509.114     213.786258

# %%
#Plot barplots for different crime on the sex variable to see the criminality rate by sex,
# and then analyze for exemple which crimes women are the most likely to commit

plt.figure(figsize=(7,5))
plt.bar(df_pdv_rates_by_sex_renamed["Sex"], df_pdv_rates_by_sex_renamed["Rate per 100k"], color='skyblue', label='Physical domestic violence')
plt.title("Average physical domestic violence MEC rate by sex (2016–2024)")
plt.xlabel("Sex")
plt.ylabel("Average MEC rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ###Drug dealing incidents

# %%
#Computation of the totals by sex (Sexe) from the two different DataFrames, on the variable drug dealing incident and on the variable population

ddi_totals = (
    pivoted_df_copy
    .groupby('Sexe')['Trafic de stupéfiants']
    .sum()
    .reset_index()
)

pop_totals = (
    df_pop_années_long
    .groupby('Sexe')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by 100 000 individuals:

df_ddi_rates_by_sex = pd.merge(ddi_totals, pop_totals, on='Sexe')

df_ddi_rates_by_sex['Rate per 100k'] = (
    df_ddi_rates_by_sex['Trafic de stupéfiants'] / (df_ddi_rates_by_sex['Population']*1000) * 100_000
)
df_ddi_rates_by_sex_renamed = df_ddi_rates_by_sex.rename(columns={
    "Trafic de stupéfiants": "Drug dealing incidents",
    "Sexe": "Sex"
    })
df_ddi_rates_by_sex_renamed
# Out:
#       Sex  Drug dealing incidents  Population  Rate per 100k
# 0  female                   36928  313428.108      11.781968
# 1    male                  378338  294081.006     128.650947
# 2   total                  415266  607509.114      68.355518

# %%
#Plot barplots for different crime on the sex variable to see the criminality rate by sex,
# and then analyze for exemple which crimes women are the most likely to commit

plt.figure(figsize=(7,5))
plt.bar(df_ddi_rates_by_sex_renamed["Sex"], df_ddi_rates_by_sex_renamed["Rate per 100k"], color='skyblue', label='Drug dealing incidents')
plt.title("Average MEC for drug dealing incidents rate by sex (2016–2024)")
plt.xlabel("Sex")
plt.ylabel("Average MEC rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ###Drug use incidents

# %%
#Computation of the totals by sex (Sexe) from the two different DataFrames, on the variable drug dealing incident and on the variable population

dui_totals = (
    pivoted_df_copy
    .groupby('Sexe')['Usage de stupéfiants']
    .sum()
    .reset_index()
)

pop_totals = (
    df_pop_années_long
    .groupby('Sexe')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by 100 000 individuals:

df_dui_rates_by_sex = pd.merge(dui_totals, pop_totals, on='Sexe')

df_dui_rates_by_sex['Rate per 100k'] = (
    df_dui_rates_by_sex['Usage de stupéfiants'] / (df_dui_rates_by_sex['Population']*1000) * 100_000
)
df_dui_rates_by_sex_renamed = df_dui_rates_by_sex.rename(columns={
    "Usage de stupéfiants": "Drug usage incidents",
    "Sexe": "Sex"
    })
df_dui_rates_by_sex_renamed
# Out:
#       Sex  Drug usage incidents  Population  Rate per 100k
# 0  female                162663  313428.108      51.898026
# 1    male               1760224  294081.006     598.550727
# 2   total               1922887  607509.114     316.519860

# %%
#Plot barplots for different crime on the sex variable to see the criminality rate by sex,
# and then analyze for exemple which crimes women are the most likely to commit

plt.figure(figsize=(7,5))
plt.bar(df_dui_rates_by_sex_renamed["Sex"], df_dui_rates_by_sex_renamed["Rate per 100k"], color='skyblue', label='Drug usage incidents')
plt.title("Average MEC for drug use incidents rate by sex (2016–2024)")
plt.xlabel("Sex")
plt.ylabel("Average MEC rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ##2.2 Nationality

# %% [markdown]
# ###2.2.1 Preliminatory work on nationality data

# %%
#Show the Excel File on the sheet nationality, in order to look at the "total" line for every year and see the trend
path = "Intro-to-data-analysis-with-Python---Final-Project/Data/mec.xlsx"

#Read Excel on the sheet 2.nationalité, skipping the first 2 rows and setting multiple headers (years and categories)
df_nationality = pd.read_excel(path, sheet_name="2.nationalité", skiprows=2, header=[0, 1])

#Remove the 1st empty column of the sheet
df_nationality = df_nationality.iloc[:,1:]

#Pivot the year header
pivoted_nationality_df = (
    df_nationality
    .set_index("Nationalité")
    .stack(level=1, future_stack=True)          # move second header to rows & future_stack=True just allow us to avoid a warning
    .reset_index()           # make it a column
    .rename(columns={"level_1": "Année"})
  )

#Cast the type of Nationalité column from tupple to string
pivoted_nationality_df["Nationalité"] = pivoted_nationality_df["Nationalité"].str[0]

pivoted_nationality_df.head(15)
# Out:
#    Nationalité  Année  \
# 0       France   2016
# 1       France   2017
# 2       France   2018
# 3       France   2019
# 4       France   2020
# 5       France   2021
# 6       France   2022
# 7       France   2023
# 8       France   2024
# 9      Afrique   2016
# 10     Afrique   2017
# 11     Afrique   2018
# 12     Afrique   2019
# 13     Afrique   2020
# 14     Afrique   2021
#
#     Homicides (y compris coups et blessures volontaires suivis de mort)  \
# 0                                               837.0
# 1                                               958.0
# 2                                               992.0
# 3                                               917.0
# 4                                               875.0
# 5                                               958.0
# 6                                              1117.0
# 7                                              1179.0
# 8                                              1189.0
# 9                                                77.0
# 10                                               75.0
# 11                                              115.0
# 12                                               97.0
# 13                                               94.0
# 14                                              113.0
#
#     Tentatives d'homicide  Violences physiques dans le cadre intra-familial  \
# 0                  1521.0                                           80605.0
# 1                  1739.0                                           82705.0
# 2                  1867.0                                           89319.0
# 3                  1926.0                                          100898.0
# 4                  2053.0                                          115523.0
# 5                  2237.0                                          136341.0
# 6                  2428.0                                          149106.0
# 7                  2835.0                                          162261.0
# 8                  2726.0                                          165667.0
# 9                   184.0                                           10426.0
# 10                  208.0                                           10922.0
# 11                  241.0                                           11403.0
# 12                  272.0                                           12901.0
# 13                  334.0                                           14371.0
# 14                  351.0                                           17948.0
#
#     Violences physiques hors cadre intra-familial  Violences sexuelles  \
# 0                                        111154.0              33198.0
# 1                                        113866.0              35564.0
# 2                                        121730.0              40837.0
# 3                                        117929.0              44042.0
# 4                                        107812.0              45623.0
# 5                                        113868.0              56989.0
# 6                                        110269.0              60985.0
# 7                                        115865.0              66672.0
# 8                                        115465.0              70609.0
# 9                                          9065.0               2657.0
# 10                                         9924.0               3026.0
# 11                                        11001.0               3591.0
# 12                                        11259.0               3942.0
# 13                                        11665.0               3974.0
# 14                                        12288.0               4883.0
#
#     Viols et tentatives de viols  Vols avec arme  Vols violents sans arme  \
# 0                         9165.0          4840.0                  15006.0
# 1                        10020.0          4903.0                  13100.0
# 2                        11732.0          4564.0                  12489.0
# 3                        12966.0          4386.0                  12453.0
# 4                        14384.0          3983.0                  10429.0
# 5                        19374.0          3858.0                  10532.0
# 6                        21723.0          3909.0                   9393.0
# 7                        24334.0          4042.0                   9553.0
# 8                        25051.0          3971.0                   9030.0
# 9                          949.0           516.0                   2607.0
# 10                        1120.0           620.0                   3186.0
# 11                        1259.0           643.0                   3787.0
# 12                        1440.0           624.0                   4104.0
# 13                        1573.0           790.0                   4778.0
# 14                        2088.0           711.0                   4615.0
#
#     Vols sans violence contre des personnes  Cambriolages de logement  \
# 0                                   56959.0                   31631.0
# 1                                   57674.0                   31114.0
# 2                                   57478.0                   29330.0
# 3                                   54554.0                   27647.0
# 4                                   46516.0                   22464.0
# 5                                   45517.0                   19381.0
# 6                                   43493.0                   18245.0
# 7                                   45647.0                   20429.0
# 8                                   44733.0                   20057.0
# 9                                    8868.0                    2851.0
# 10                                  10607.0                    3884.0
# 11                                  12233.0                    4329.0
# 12                                  14159.0                    4623.0
# 13                                  12941.0                    6496.0
# 14                                  13681.0                    7128.0
#
#     Vols de véhicule  Vols dans les véhicule  \
# 0            24097.0                 20775.0
# 1            21623.0                 21300.0
# 2            23593.0                 21134.0
# 3            20758.0                 18575.0
# 4            18569.0                 16024.0
# 5            18713.0                 15036.0
# 6            17566.0                 14742.0
# 7            20950.0                 12845.0
# 8            21331.0                 14679.0
# 9              918.0                  2866.0
# 10             918.0                  3562.0
# 11             882.0                  4461.0
# 12             941.0                  5084.0
# 13            1152.0                  5422.0
# 14            1080.0                  5918.0
#
#     Vols d'accessoires sur les véhicules  \
# 0                                 6319.0
# 1                                 6705.0
# 2                                 7577.0
# 3                                 7172.0
# 4                                 5728.0
# 5                                 4442.0
# 6                                 5728.0
# 7                                 6055.0
# 8                                 5981.0
# 9                                  269.0
# 10                                 276.0
# 11                                 284.0
# 12                                 246.0
# 13                                 265.0
# 14                                 190.0
#
#     Destructions et dégradations volontaires  \
# 0                                    70553.0
# 1                                    76188.0
# 2                                    77280.0
# 3                                    77285.0
# 4                                    69519.0
# 5                                    66177.0
# 6                                    62675.0
# 7                                    66005.0
# 8                                    61988.0
# 9                                     4021.0
# 10                                    4334.0
# 11                                    5165.0
# 12                                    5488.0
# 13                                    5853.0
# 14                                    5972.0
#
#     Escroqueries et fraudes aux moyens de paiements  Trafic de stupéfiants  \
# 0                                           54998.0                35718.0
# 1                                           55306.0                38124.0
# 2                                           53152.0                38565.0
# 3                                           52689.0                39681.0
# 4                                           45892.0                34995.0
# 5                                           47881.0                38949.0
# 6                                           43262.0                39531.0
# 7                                           42404.0                38809.0
# 8                                           41289.0                41001.0
# 9                                            5071.0                 2857.0
# 10                                           5299.0                 3347.0
# 11                                           4546.0                 3903.0
# 12                                           4418.0                 4349.0
# 13                                           4040.0                 3752.0
# 14                                           4350.0                 5184.0
#
#     Usage de stupéfiants
# 0               166710.0
# 1               171291.0
# 2               167786.0
# 3               158287.0
# 4               143491.0
# 5               196022.0
# 6               219482.0
# 7               233135.0
# 8               254170.0
# 9                 9498.0
# 10               10558.0
# 11               11801.0
# 12               12239.0
# 13               11232.0
# 14               16969.0

# %%
#Analyze the evolution of criminality with taking into account change in population. A new excel has to be downloaded, showing the structure of population by nationality:
path = "Intro-to-data-analysis-with-Python---Final-Project/Data/pop_e.xlsx"

xls_pop_e = pd.ExcelFile(path)
xls_pop_e.sheet_names
# Out:
# ['Sommaire',
#  'Figure 1',
#  'Figure 2',
#  'Figure 3',
#  'Figure 4',
#  'Figure 5',
#  'Figure 6',
#  'Question 1',
#  'Question 2',
#  'Question 3',
#  'Question 4',
#  'Question 5',
#  'Question 6']

# %%
#Show the Excel File on the sheet Figure 5 – Population étrangère et immigrée en France, in order to look at the "Etrangers, effectif (en milliers)" column for every year between 2016 to 2024
df_pop_e = pd.read_excel(path, sheet_name="Figure 5", skiprows=2, header=[0])
df_pop_e = df_pop_e[0:-5] #Remove the last 5 rows which contained strings
df_pop_e = df_pop_e.iloc[1:].reset_index(drop=True)
df_pop_e = df_pop_e.drop(df_pop_e.columns[[2, 3, 4, 5, 6, 7]], axis=1)

df_pop_e.head(10)
# Out:
#       Année Étrangers
# 0  2024 (p)      6028
# 1  2023 (p)      5622
# 2      2022      5331
# 3      2021    5235.9
# 4      2020    5149.2
# 5      2019      5000
# 6      2018    4849.9
# 7      2017    4703.8
# 8      2016    4541.5
# 9      2015    4427.9

# %%
df_pop_e_années = df_pop_e.loc[0:8]
display(df_pop_e_années)
# Out:
#       Année Étrangers
# 0  2024 (p)      6028
# 1  2023 (p)      5622
# 2      2022      5331
# 3      2021    5235.9
# 4      2020    5149.2
# 5      2019      5000
# 6      2018    4849.9
# 7      2017    4703.8
# 8      2016    4541.5

# %%
# Convert 'Année' to string, then remove "(p)" if present, then convert to int
# Clean both DataFrames
for df in [df_pop_années_ensemble, df_pop_e_années]:
    df['Année'] = df['Année'].astype(str).str.replace(r" \([pP]\)", "", regex=True).astype(int)
# Out:
# /tmp/ipython-input-1104563096.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Année'] = df['Année'].astype(str).str.replace(r" \([pP]\)", "", regex=True).astype(int)
# /tmp/ipython-input-1104563096.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Année'] = df['Année'].astype(str).str.replace(r" \([pP]\)", "", regex=True).astype(int)

# %%
df_pop_ensemble_e_merged = pd.merge(
    df_pop_années_ensemble,
    df_pop_e_années,
    on="Année",
    how="left"  # keeps all years from left DF
)
df_pop_ensemble_e_merged.head(10)
# Out:
#    Année   Ensemble Étrangers
# 0   2024  68436.616      6028
# 1   2023  68246.082      5622
# 2   2022  68060.207      5331
# 3   2021  67697.091    5235.9
# 4   2020  67441.850    5149.2
# 5   2019  67257.982      5000
# 6   2018  66992.159    4849.9
# 7   2017  66774.482    4703.8
# 8   2016  66602.645    4541.5

# %%
#Calculating the number of the population that is not foreign
df_pop_ensemble_e_merged['Français'] = (
    df_pop_ensemble_e_merged['Ensemble'] - df_pop_ensemble_e_merged['Étrangers']
)
df_pop_ensemble_e_merged.head()
# Out:
#    Année   Ensemble Étrangers   Français
# 0   2024  68436.616      6028  62408.616
# 1   2023  68246.082      5622  62624.082
# 2   2022  68060.207      5331  62729.207
# 3   2021  67697.091    5235.9  62461.191
# 4   2020  67441.850    5149.2   62292.65

# %%
#Reshaping the population data in long format (vs. wide format, where each category is in a separate column),
#so that each variable is in a single column, and there’s a column that indicates the category (Nationalité):
df_pop_ensemble_e_long = df_pop_ensemble_e_merged.melt(
    id_vars='Année',
    value_vars=['Étrangers', 'Français', 'Ensemble'],
    var_name='Nationalité',
    value_name='Population'
)
df_pop_ensemble_e_long.head(30)
# Out:
#     Année Nationalité Population
# 0    2024   Étrangers       6028
# 1    2023   Étrangers       5622
# 2    2022   Étrangers       5331
# 3    2021   Étrangers     5235.9
# 4    2020   Étrangers     5149.2
# 5    2019   Étrangers       5000
# 6    2018   Étrangers     4849.9
# 7    2017   Étrangers     4703.8
# 8    2016   Étrangers     4541.5
# 9    2024    Français  62408.616
# 10   2023    Français  62624.082
# 11   2022    Français  62729.207
# 12   2021    Français  62461.191
# 13   2020    Français   62292.65
# 14   2019    Français  62257.982
# 15   2018    Français  62142.259
# 16   2017    Français  62070.682
# 17   2016    Français  62061.145
# 18   2024    Ensemble  68436.616
# 19   2023    Ensemble  68246.082
# 20   2022    Ensemble  68060.207
# 21   2021    Ensemble  67697.091
# 22   2020    Ensemble   67441.85
# 23   2019    Ensemble  67257.982
# 24   2018    Ensemble  66992.159
# 25   2017    Ensemble  66774.482
# 26   2016    Ensemble  66602.645

# %%
nationality_mapping = {
    'France': 'French',
    'Français': 'French',
    'Afrique': 'Foreigners',
    'Amérique , Océanie': 'Foreigners',
    'Asie': 'Foreigners',
    'Europe hors UE': 'Foreigners',
    'UE hors France': 'Foreigners',
    'Étrangers': 'Foreigners',
    'Ensemble': 'Total',
    'Total': 'Total'
    }

# %%
df_pop_ensemble_e_long['Nationalité'] = df_pop_ensemble_e_long['Nationalité'].map(nationality_mapping)

pivoted_nationality_df['Nationalité'] = pivoted_nationality_df['Nationalité'].map(nationality_mapping)

# %% [markdown]
# ###2.2.2 Visualisation

# %% [markdown]
# ####Sexual violences

# %%
#Computation of the totals (for the whole period 2016-2024) by nationality (Nationalité) from the two different DataFrames, on the variable violences sexuelles and on the variable population

nat_sv_totals = (
    pivoted_nationality_df
    .groupby('Nationalité')['Violences sexuelles']
    .sum()
    .reset_index()
)

nat_pop_totals = (
    df_pop_ensemble_e_long
    .groupby('Nationalité')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by nationality for 100 000 individuals:

df_sv_rates_by_nationality = pd.merge(nat_sv_totals, nat_pop_totals, on='Nationalité')

df_sv_rates_by_nationality['Rate per 100k'] = (
    df_sv_rates_by_nationality['Violences sexuelles'] / (df_sv_rates_by_nationality['Population']*1000) * 100_000
)
df_sv_rates_by_nationality_renamed = df_sv_rates_by_nationality.rename(columns={
    "Violences sexuelles": "Sexual violences",
    "Nationalité": "Nationality"
    })
df_sv_rates_by_nationality_renamed
# Out:
#   Nationality  Sexual violences  Population Rate per 100k
# 0  Foreigners           69244.0     46461.3    149.035864
# 1      French          454519.0  561047.814     81.012525
# 2       Total          523763.0  607509.114     86.214838

# %%
#Plot barplots for different crime on the nationality variable to see the criminality rate by nationality,
# and then analyze for exemple which crimes there is a surrepresentation of foreigners/French

plt.figure(figsize=(7,5))
plt.bar(df_sv_rates_by_nationality_renamed["Nationality"], df_sv_rates_by_nationality_renamed["Rate per 100k"], color='skyblue', label='Sexual violence')
plt.title("Average sexual violences rate by nationality (2016–2024)")
plt.xlabel("Nationality")
plt.ylabel("Average rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ####Homicides

# %%
#Computation of the totals (for the whole period 2016-2024) by nationality (Nationalité) from the two different DataFrames, on the variable homicides and on the variable population

nat_hom_totals = (
    pivoted_nationality_df
    .groupby('Nationalité')['Homicides (y compris coups et blessures volontaires suivis de mort)']
    .sum()
    .reset_index()
)

nat_pop_totals = (
    df_pop_ensemble_e_long
    .groupby('Nationalité')['Population']
    .sum()
    .reset_index()
)

# %%
#Compute the rate by nationality for 100 000 individuals:

df_hom_rates_by_nationality = pd.merge(nat_hom_totals, nat_pop_totals, on='Nationalité')

df_hom_rates_by_nationality['Rate per 100k'] = (
    df_hom_rates_by_nationality['Homicides (y compris coups et blessures volontaires suivis de mort)'] / (df_hom_rates_by_nationality['Population']*1000) * 100_000
)
df_hom_rates_by_nationality_renamed = df_hom_rates_by_nationality.rename(columns={
    "Homicides (y compris coups et blessures volontaires suivis de mort)": "Homicides",
    "Nationalité": "Nationality"
    })
df_hom_rates_by_nationality_renamed
# Out:
#   Nationality  Homicides  Population Rate per 100k
# 0  Foreigners     1898.0     46461.3       4.08512
# 1      French     9022.0  561047.814      1.608063
# 2       Total    10920.0  607509.114      1.797504

# %%
#Plot barplots for different crime on the nationality variable to see the criminality rate by nationality,
# and then analyze for exemple which crimes there is a surrepresentation of foreigners/French

plt.figure(figsize=(7,5))
plt.bar(df_hom_rates_by_nationality_renamed["Nationality"], df_hom_rates_by_nationality_renamed["Rate per 100k"], color='skyblue', label='Homicides')
plt.title("Average homicides rate by nationality (2016–2024)")
plt.xlabel("Nationality")
plt.ylabel("Average rate for 2016-2024")
plt.legend()
plt.show()

# %% [markdown]
# ####Non-violent theft rate

# %%
#After discussing with more advanced Python users, I realized I could create a function to factorize common code:

NAT_POP_TOTALS = (
    df_pop_ensemble_e_long
    .groupby('Nationalité')['Population']
    .sum()
    .reset_index()
)

def compute_total_for_crime_by_nationality(label):

  nat_offense_totals = (
      pivoted_nationality_df
      .groupby('Nationalité')[label]
      .sum()
      .reset_index()
  )

  return (nat_offense_totals)

#Compute the rate by nationality for 100 000 individuals:
def compute_crime_rate_by_nationality(nat_offense_totals, label, newLabel, nationalityNewLabel = "Nationality"):

  df_crime_rates_by_nationality = pd.merge(nat_offense_totals, NAT_POP_TOTALS, on='Nationalité')
  df_crime_rates_by_nationality['Rate per 100k'] = (
      df_crime_rates_by_nationality[label] / (df_crime_rates_by_nationality['Population']*1000) * 100_000
  )
  df_crime_rates_by_nationality_renamed = df_crime_rates_by_nationality.rename(columns={
      label: newLabel,
      "Nationalité": nationalityNewLabel
      })
  return df_crime_rates_by_nationality_renamed

#Plot barplots for different crime on the nationality variable to see the criminality rate by nationality,
# and then analyze for exemple which crimes there is a surrepresentation of foreigners/French

def plot_crime_rates_by_nationality(df_crime_rates_by_nationality_renamed, newLabel):
  plt.figure(figsize=(7,5))
  plt.bar(df_crime_rates_by_nationality_renamed["Nationality"], df_crime_rates_by_nationality_renamed["Rate per 100k"], color='skyblue', label=newLabel)
  plt.title(f"Average {newLabel} rate by nationality (2016–2024)")
  plt.xlabel("Nationality")
  plt.ylabel("Average rate for 2016-2024")
  plt.legend()
  plt.show()

# %%
label = 'Vols sans violence contre des personnes'
newLabel = "Non-violent theft"
nat_nvt_totals = compute_total_for_crime_by_nationality(label)
df_nvt_rate_by_nationality = compute_crime_rate_by_nationality(nat_nvt_totals, label, newLabel)
plot_crime_rates_by_nationality(df_nvt_rate_by_nationality, newLabel)
df_nvt_rate_by_nationality
# Out:
#   Nationality  Non-violent theft  Population Rate per 100k
# 0  Foreigners           175816.0     46461.3    378.413863
# 1      French           452571.0  561047.814     80.665317
# 2       Total           628387.0  607509.114    103.436637

# %% [markdown]
# ####Physical domestic violence:

# %%
label = 'Violences physiques dans le cadre intra-familial'
newLabel = "Physical domestic violence"
nat_pdv_totals = compute_total_for_crime_by_nationality(label)
df_pdv_rate_by_nationality = compute_crime_rate_by_nationality(nat_pdv_totals, label, newLabel)
plot_crime_rates_by_nationality(df_pdv_rate_by_nationality, newLabel)
df_pdv_rate_by_nationality
# Out:
#   Nationality  Physical domestic violence  Population Rate per 100k
# 0  Foreigners                    225609.0     46461.3    485.584777
# 1      French                   1082425.0  561047.814    192.929189
# 2       Total                   1298771.0  607509.114    213.786258

# %% [markdown]
# ####Drug dealing incident

# %%
label = 'Trafic de stupéfiants'
newLabel = "Drug dealing incident"
nat_ddi_totals = compute_total_for_crime_by_nationality(label)
df_ddi_rate_by_nationality = compute_crime_rate_by_nationality(nat_ddi_totals, label, newLabel)
plot_crime_rates_by_nationality(df_ddi_rate_by_nationality, newLabel)
df_ddi_rate_by_nationality
# Out:
#   Nationality  Drug dealing incident  Population Rate per 100k
# 0  Foreigners                69893.0     46461.3    150.432726
# 1      French               345373.0  561047.814     61.558568
# 2       Total               415266.0  607509.114     68.355518

# %% [markdown]
# ####Drug use incidents

# %%
label = 'Usage de stupéfiants'
newLabel = "Drug usage incident"
nat_dui_totals = compute_total_for_crime_by_nationality(label)
df_dui_rate_by_nationality = compute_crime_rate_by_nationality(nat_dui_totals, label, newLabel)
plot_crime_rates_by_nationality(df_dui_rate_by_nationality, newLabel)
df_dui_rate_by_nationality
# Out:
#   Nationality  Drug usage incident  Population Rate per 100k
# 0  Foreigners             212514.0     46461.3     457.40003
# 1      French            1710374.0  561047.814    304.853518
# 2       Total            1922888.0  607509.114    316.520025

# %% [markdown]
# ##2.3 Age

# %% [markdown]
# ###2.3.1 Preliminatory work on age data

# %%
#Read Excel File - total accused people and display the sheets' names

path = "Intro-to-data-analysis-with-Python---Final-Project/Data/mec.xlsx"

xls = pd.ExcelFile(path)
xls.sheet_names
# Out:
# ['Lisez moi',
#  '1.sexe - age',
#  '2.nationalité',
#  '3.sexe',
#  '4.nationalité majmin',
#  '5.PM - PP']

# %%
#Show the Excel File on the sheet age, in order to look at the "total" line for each category of offense by age range and see the trend

#Read Excel on the sheet 1.sexe - age, skipping the first 2 rows and setting multiple headers (sex, year and categories)
df_age = pd.read_excel(path, sheet_name="1.sexe - age", skiprows=2, header=[0, 1])

print(df_age.columns[:5])

#Remove the 1st empty column of the sheet
df_age = df_age.iloc[:,1:]

#Flatten MultiIndex : merge both level with "_", ignore empty
df_age.columns = ['_'.join([str(i) for i in col if i]).strip() for col in df_age.columns]

print(df_age.columns[:5])

#Fill columns properly and rename them

df_age["Sexe_Unnamed: 1_level_1"] = df_age["Sexe_Unnamed: 1_level_1"].ffill()
df_age["Age_Unnamed: 2_level_1"] = df_age["Age_Unnamed: 2_level_1"].ffill()

df_age = df_age.rename(columns={
    "Sexe_Unnamed: 1_level_1": "Sexe",
    "Age_Unnamed: 2_level_1": "Age"
})

#Vérify the result
print(df_age.columns[:5])
# Out:
# MultiIndex([(                                                 'Unnamed: 0_level_0', ...),
#             (                                                               'Sexe', ...),
#             (                                                                'Age', ...),
#             ('Homicides (y compris coups et blessures volontaires suivis de mort)', ...),
#             ('Homicides (y compris coups et blessures volontaires suivis de mort)', ...)],
#            )
# Index(['Sexe_Unnamed: 1_level_1', 'Age_Unnamed: 2_level_1',
#        'Homicides (y compris coups et blessures volontaires suivis de mort)_2016',
#        'Homicides (y compris coups et blessures volontaires suivis de mort)_2017',
#        'Homicides (y compris coups et blessures volontaires suivis de mort)_2018'],
#       dtype='object')
# Index(['Sexe', 'Age',
#        'Homicides (y compris coups et blessures volontaires suivis de mort)_2016',
#        'Homicides (y compris coups et blessures volontaires suivis de mort)_2017',
#        'Homicides (y compris coups et blessures volontaires suivis de mort)_2018'],
#       dtype='object')

# %%
#Define identification columns

id_vars_age = ["Sexe", "Age"]
value_vars_age = [col for col in df_age.columns if col not in id_vars_age]

#Transform table into long version
df_long_age = df_age.melt(
    id_vars=id_vars_age,
    value_vars=value_vars_age,
    var_name="Infraction_Année",
    value_name="Nombre"
)

#Separate infraction and year
df_long_age[["Infraction", "Année"]] = df_long_age["Infraction_Année"].str.rsplit("_", n=1, expand=True)
df_long_age["Année"] = df_long_age["Année"].astype(int)
df_long_age = df_long_age.drop(columns="Infraction_Année")

#Verification
df_long_age.head()
# Out:
#      Sexe              Age Nombre  \
# 0  Femmes  Moins de 13 ans    0.0
# 1  Femmes      13 à 17 ans    9.0
# 2  Femmes      18 à 29 ans   42.0
# 3  Femmes      30 à 44 ans   55.0
# 4  Femmes      45 à 59 ans   17.0
#
#                                           Infraction  Année
# 0  Homicides (y compris coups et blessures volont...   2016
# 1  Homicides (y compris coups et blessures volont...   2016
# 2  Homicides (y compris coups et blessures volont...   2016
# 3  Homicides (y compris coups et blessures volont...   2016
# 4  Homicides (y compris coups et blessures volont...   2016

# %%
#Filter for adults between 18-59

adultes = ["18 à 29 ans", "30 à 44 ans", "45 à 59 ans"]
df_adultes = df_long_age[df_long_age["Age"].isin(adultes)]

#Verification
df_adultes.head()
# Out:
#      Sexe          Age Nombre  \
# 2  Femmes  18 à 29 ans   42.0
# 3  Femmes  30 à 44 ans   55.0
# 4  Femmes  45 à 59 ans   17.0
# 8  Hommes  18 à 29 ans  386.0
# 9  Hommes  30 à 44 ans  236.0
#
#                                           Infraction  Année
# 2  Homicides (y compris coups et blessures volont...   2016
# 3  Homicides (y compris coups et blessures volont...   2016
# 4  Homicides (y compris coups et blessures volont...   2016
# 8  Homicides (y compris coups et blessures volont...   2016
# 9  Homicides (y compris coups et blessures volont...   2016

# %%
#Visualize just the total lines
df_total = df_adultes[df_adultes["Sexe"] == "Total"]
display(df_total)
# Out:
#        Sexe          Age    Nombre  \
# 14    Total  18 à 29 ans     428.0
# 15    Total  30 à 44 ans     291.0
# 16    Total  45 à 59 ans     150.0
# 33    Total  18 à 29 ans       470
# 34    Total  30 à 44 ans       319
# ...     ...          ...       ...
# 2884  Total  30 à 44 ans   61809.0
# 2885  Total  45 à 59 ans   14707.0
# 2902  Total  18 à 29 ans  185560.0
# 2903  Total  30 à 44 ans   71684.0
# 2904  Total  45 à 59 ans   17360.0
#
#                                              Infraction  Année
# 14    Homicides (y compris coups et blessures volont...   2016
# 15    Homicides (y compris coups et blessures volont...   2016
# 16    Homicides (y compris coups et blessures volont...   2016
# 33    Homicides (y compris coups et blessures volont...   2017
# 34    Homicides (y compris coups et blessures volont...   2017
# ...                                                 ...    ...
# 2884                               Usage de stupéfiants   2023
# 2885                               Usage de stupéfiants   2023
# 2902                               Usage de stupéfiants   2024
# 2903                               Usage de stupéfiants   2024
# 2904                               Usage de stupéfiants   2024
#
# [459 rows x 5 columns]

# %% [markdown]
# ###2.3.2 Visualisation

# %% [markdown]
# ####Age repartition in 2024

# %%
# Filter targeted infractions
infractions_cibles = [
    "Homicides (y compris coups et blessures volontaires suivis de mort)",
    "Violences sexuelles",
    "Violences physiques  intrafamiliales",
    "Vols sans violence contre des personnes",
    "Trafic de stupéfiants",
    "Usage de stupéfiants"
]

# Filter for year 2024
df_2024 = df_total[
    (df_total["Année"] == 2024) &
    (df_total["Infraction"].isin(infractions_cibles))
]

# Calculate the proportion of each age range for each infraction type
df_2024_prop = df_2024.copy()
df_2024_prop["Total_Infraction"] = df_2024_prop.groupby("Infraction")["Nombre"].transform("sum")
df_2024_prop["Proportion"] = df_2024_prop["Nombre"] / df_2024_prop["Total_Infraction"]

# Plot barplots
plt.figure(figsize=(12,6))

# Pivot
df_pivot = df_2024_prop.pivot(index="Infraction", columns="Age", values="Proportion")
df_pivot.plot(kind="bar", stacked=True, colormap="tab20", figsize=(12,6))

plt.ylabel("Proportion par tranche d'âge")
plt.xlabel("Type d'infraction")
plt.title("Répartition par tranche d'âge des infractions en 2024")
plt.legend(title="Tranche d'âge")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# Filter targeted infractions
infractions_cibles = [
    "Homicides (y compris coups et blessures volontaires suivis de mort)",
    "Violences sexuelles",
    "Violences physiques  intrafamiliales",
    "Vols sans violence contre des personnes",
    "Trafic de stupéfiants",
    "Usage de stupéfiants"
]

# Filter for year 2016
df_2024 = df_total[
    (df_total["Année"] == 2016) &
    (df_total["Infraction"].isin(infractions_cibles))
]

# Calculate the proportion of each age range for each infraction type
df_2016_prop = df_2016.copy()
df_2016_prop["Total_Infraction"] = df_2016_prop.groupby("Infraction")["Nombre"].transform("sum")
df_2016_prop["Proportion"] = df_2016_prop["Nombre"] / df_2016_prop["Total_Infraction"]

# Plot barplots
plt.figure(figsize=(12,6))

# Pivot
df_pivot = df_2024_prop.pivot(index="Infraction", columns="Age", values="Proportion")
df_pivot.plot(kind="bar", stacked=True, colormap="tab20", figsize=(12,6))

plt.ylabel("Proportion par tranche d'âge")
plt.xlabel("Type d'infraction")
plt.title("Répartition par tranche d'âge des infractions en 2016")
plt.legend(title="Tranche d'âge")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ####Comparison of age range repartition between 2016 and 2024

# %%
# Year to compare
annees_cibles = [2016, 2024]

# Filter total for year
df_compare = df_total[
    (df_total["Année"].isin(annees_cibles)) &
    (df_total["Infraction"].isin(infractions_cibles))
].copy()

# Total by infraction et by year
df_compare["Total_Infraction_Année"] = (
    df_compare
    .groupby(["Infraction", "Année"])["Nombre"]
    .transform("sum")
)

# Calculate proportion for each age range
df_compare["Proportion"] = (
    df_compare["Nombre"] / df_compare["Total_Infraction_Année"]
)

df_compare.head()
# Out:
#       Sexe          Age Nombre  \
# 14   Total  18 à 29 ans  428.0
# 15   Total  30 à 44 ans  291.0
# 16   Total  45 à 59 ans  150.0
# 166  Total  18 à 29 ans    642
# 167  Total  30 à 44 ans    413
#
#                                             Infraction  Année  \
# 14   Homicides (y compris coups et blessures volont...   2016
# 15   Homicides (y compris coups et blessures volont...   2016
# 16   Homicides (y compris coups et blessures volont...   2016
# 166  Homicides (y compris coups et blessures volont...   2024
# 167  Homicides (y compris coups et blessures volont...   2024
#
#     Total_Infraction_Année Proportion
# 14                   869.0    0.49252
# 15                   869.0   0.334868
# 16                   869.0   0.172612
# 166                   1222   0.525368
# 167                   1222   0.337971

# %%
#Visualise the evolution of age range repartition between year 2016 and 2024
ages_ordre = ["18 à 29 ans", "30 à 44 ans", "45 à 59 ans"]

for infraction in infractions_cibles:

    df_inf = df_compare[df_compare["Infraction"] == infraction]

    # Pivot
    df_pivot = df_inf.pivot(
        index="Age",
        columns="Année",
        values="Proportion"
    ).reindex(ages_ordre)

    # Ploting our figure
    fig, ax = plt.subplots(figsize=(6,4))

    df_pivot.plot(
        kind="bar",
        ax=ax
    )

    ax.set_title(
        f"Évolution de la structure par âge\n{infraction} (2016–2024)"
    )
    ax.set_ylabel("Part des MEC")
    ax.set_xlabel("Tranche d'âge")
    ax.legend(title="Année")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Part 3: For which groups is it possible to see an increase in committing crimes

# %% [markdown]
# ##3.1 Nationality

# %%
#Diagnosing the column: shows what values are actually in the Nationalité column
pivoted_nationality_df['Nationalité'].value_counts(dropna=False)
# Out:
# Nationalité
# Foreigners    45
# French         9
# Total          9
# NaN            9
# Name: count, dtype: int64

# %%
total_table_by_nationality = (
    pivoted_nationality_df
    .assign(
        Total_crimes=lambda d: d[d.columns.difference(['Année', 'Nationalité'])].sum(axis=1)
    )
    .groupby(['Nationalité', 'Année'])['Total_crimes']
    .sum()
    .reset_index()
)
total_table_by_nationality
# Out:
#    Nationalité  Année  Total_crimes
# 0   Foreigners   2016      117046.0
# 1   Foreigners   2017      128209.0
# 2   Foreigners   2018      141194.0
# 3   Foreigners   2019      144998.0
# 4   Foreigners   2020      141133.0
# 5   Foreigners   2021      163030.0
# 6   Foreigners   2022      179156.0
# 7   Foreigners   2023      178842.0
# 8   Foreigners   2024      182689.0
# 9       French   2016      724086.0
# 10      French   2017      742180.0
# 11      French   2018      759425.0
# 12      French   2019      752165.0
# 13      French   2020      703880.0
# 14      French   2021      796275.0
# 15      French   2022      823654.0
# 16      French   2023      873020.0
# 17      French   2024      898937.0
# 18       Total   2016      840343.0
# 19       Total   2017      869505.0
# 20       Total   2018      899641.0
# 21       Total   2019      895980.0
# 22       Total   2020      843598.0
# 23       Total   2021      957679.0
# 24       Total   2022     1000978.0
# 25       Total   2023     1049793.0
# 26       Total   2024     1079448.0

# %%
#Compute the crime rate by nationality for 100 000 individuals by year:

df_crime_rates_by_nationality_by_year = pd.merge(total_table_by_nationality, df_pop_ensemble_e_long, on=['Nationalité', 'Année'])

df_crime_rates_by_nationality_by_year['Rate per 100k'] = (
    df_crime_rates_by_nationality_by_year['Total_crimes'] / (df_crime_rates_by_nationality_by_year['Population']*1000) * 100_000
)
df_crime_rates_by_nationality_by_year_renamed = df_crime_rates_by_nationality_by_year.rename(columns={
    "Nationalité": "Nationality",
    "Année": "Year"
    })
df_crime_rates_by_nationality_by_year_renamed
# Out:
#    Nationality  Year  Total_crimes Population Rate per 100k
# 0   Foreigners  2016      117046.0     4541.5   2577.254211
# 1   Foreigners  2017      128209.0     4703.8   2725.647349
# 2   Foreigners  2018      141194.0     4849.9   2911.276521
# 3   Foreigners  2019      144998.0       5000       2899.96
# 4   Foreigners  2020      141133.0     5149.2   2740.872369
# 5   Foreigners  2021      163030.0     5235.9   3113.695831
# 6   Foreigners  2022      179156.0       5331   3360.645282
# 7   Foreigners  2023      178842.0       5622   3181.109925
# 8   Foreigners  2024      182689.0       6028   3030.673524
# 9       French  2016      724086.0  62061.145   1166.730005
# 10      French  2017      742180.0  62070.682   1195.701378
# 11      French  2018      759425.0  62142.259   1222.074981
# 12      French  2019      752165.0  62257.982   1208.142275
# 13      French  2020      703880.0   62292.65   1129.956744
# 14      French  2021      796275.0  62461.191   1274.831599
# 15      French  2022      823654.0  62729.207   1313.031105
# 16      French  2023      873020.0  62624.082   1394.064347
# 17      French  2024      898937.0  62408.616    1440.40528
# 18       Total  2016      840343.0  66602.645   1261.726167
# 19       Total  2017      869505.0  66774.482   1302.151621
# 20       Total  2018      899641.0  66992.159   1342.904921
# 21       Total  2019      895980.0  67257.982   1332.154152
# 22       Total  2020      843598.0   67441.85   1250.852401
# 23       Total  2021      957679.0  67697.091   1414.653105
# 24       Total  2022     1000978.0  68060.207   1470.724296
# 25       Total  2023     1049793.0  68246.082   1538.246547
# 26       Total  2024     1079448.0  68436.616    1577.29599

# %%
# Visualise the data into a graph
plt.figure(figsize=(8, 5))

for nationality in df_crime_rates_by_nationality_by_year_renamed['Nationality'].unique():
    df_subset = df_crime_rates_by_nationality_by_year_renamed[
        df_crime_rates_by_nationality_by_year_renamed['Nationality'] == nationality
    ]

    plt.plot(
        df_subset['Year'],
        df_subset['Rate per 100k'],
        marker='o',
        label=nationality
    )

plt.title("Evolution of MEC rate by nationality (2016–2024)")
plt.xlabel("Year")
plt.ylabel("MEC rate per 100k")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##3.2 Sex

# %%
pivoted_df_copy_2 = pivoted_df.copy()

# %%
sex_mapping = {
    'Femmes': 'female',
    'Femme': 'female',
    'female': 'female',
    'Hommes': 'male',
    'Homme': 'male',
    'male': 'male',
    'Ensemble': 'total',
    'Total': 'total',
    'total': 'total'
    }


df_pop_années_long['Sexe'] = df_pop_années_long['Sexe'].map(sex_mapping)

pivoted_df_copy_2['Sexe'] = pivoted_df_copy_2['Sexe'].map(sex_mapping)

# %%
total_table_by_sex = (
    pivoted_df_copy_2
    .assign(
        Total_crimes=lambda d: d[d.columns.difference(['Année', 'Sexe'])].sum(axis=1)
    )
    .groupby(['Sexe', 'Année'])['Total_crimes']
    .sum()
    .reset_index()
)
total_table_by_sex
# Out:
#       Sexe  Année  Total_crimes
# 0   female   2016        111008
# 1   female   2017        113814
# 2   female   2018        116038
# 3   female   2019        115842
# 4   female   2020        107233
# 5   female   2021        119578
# 6   female   2022        120827
# 7   female   2023        133331
# 8   female   2024        136836
# 9     male   2016        729335
# 10    male   2017        755691
# 11    male   2018        783603
# 12    male   2019        780138
# 13    male   2020        736365
# 14    male   2021        838100
# 15    male   2022        880151
# 16    male   2023        916462
# 17    male   2024        942612
# 18   total   2016        840343
# 19   total   2017        869505
# 20   total   2018        899641
# 21   total   2019        895980
# 22   total   2020        843598
# 23   total   2021        957678
# 24   total   2022       1000978
# 25   total   2023       1049793
# 26   total   2024       1079448

# %%
#Compute the crime rate by sex for 100 000 individuals by year:

df_crime_rates_by_sex_by_year = pd.merge(total_table_by_sex, df_pop_années_long, on=['Sexe', 'Année'])

df_crime_rates_by_sex_by_year['Rate per 100k'] = (
    df_crime_rates_by_sex_by_year['Total_crimes'] / (df_crime_rates_by_sex_by_year['Population']*1000) * 100_000
)
df_crime_rates_by_sex_by_year_renamed = df_crime_rates_by_sex_by_year.rename(columns={
    "Sexe": "Sex",
    "Année": "Year"
    })
df_crime_rates_by_sex_by_year_renamed

display(df_crime_rates_by_sex_by_year_renamed)
# Out:
#        Sex  Year  Total_crimes  Population  Rate per 100k
# 0   female  2016        111008   34372.558     322.955306
# 1   female  2017        113814   34477.222     330.113604
# 2   female  2018        116038   34594.401     335.424221
# 3   female  2019        115842   34722.069     333.626432
# 4   female  2020        107233   34812.046     308.034179
# 5   female  2021        119578   34930.005     342.336052
# 6   female  2022        120827   35092.520     344.309842
# 7   female  2023        133331   35172.311     379.079441
# 8   female  2024        136836   35254.976     388.132444
# 9     male  2016        729335   32230.087    2262.901121
# 10    male  2017        755691   32297.260    2339.799104
# 11    male  2018        783603   32397.758    2418.695146
# 12    male  2019        780138   32535.913    2397.775037
# 13    male  2020        736365   32629.804    2256.725171
# 14    male  2021        838100   32767.086    2557.749566
# 15    male  2022        880151   32967.687    2669.738402
# 16    male  2023        916462   33073.771    2770.963130
# 17    male  2024        942612   33181.640    2840.763748
# 18   total  2016        840343   66602.645    1261.726167
# 19   total  2017        869505   66774.482    1302.151621
# 20   total  2018        899641   66992.159    1342.904921
# 21   total  2019        895980   67257.982    1332.154152
# 22   total  2020        843598   67441.850    1250.852401
# 23   total  2021        957678   67697.091    1414.651628
# 24   total  2022       1000978   68060.207    1470.724296
# 25   total  2023       1049793   68246.082    1538.246547
# 26   total  2024       1079448   68436.616    1577.295990

# %%
# Visualise the data into a graph
plt.figure(figsize=(8, 5))

for sex in df_crime_rates_by_sex_by_year_renamed['Sex'].unique():
    df_subset_sex = df_crime_rates_by_sex_by_year_renamed[
        df_crime_rates_by_sex_by_year_renamed['Sex'] == sex
    ]

    plt.plot(
        df_subset_sex['Year'],
        df_subset_sex['Rate per 100k'],
        marker='o',
        label=sex
    )

plt.title("Evolution of MEC rate by sex (2016–2024)")
plt.xlabel("Year")
plt.ylabel("Number of MEC rate per 100k")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##3.3 Age

# %%
# Selction of age ranges
ages_ordre = ["18 à 29 ans", "30 à 44 ans", "45 à 59 ans"]

# from df_total (Sexe = Total, adultes)
df_age_time = df_total.copy()

# group the total number of infraction (all age ranges together)
df_age_time["Total_Année"] = (
    df_age_time
    .groupby("Année")["Nombre"]
    .transform("sum")
)

# Select the proportion by age range for each age range
df_age_time["Proportion"] = (
    df_age_time["Nombre"] / df_age_time["Total_Année"]
)

df_age_time = (
    df_age_time
    .groupby(["Année", "Age"], as_index=False)["Proportion"]
    .sum()
)

# Reorganise age
df_age_time["Age"] = pd.Categorical(
    df_age_time["Age"],
    categories=ages_ordre,
    ordered=True
)

df_age_time.head()
# Out:
#    Année          Age Proportion
# 0   2016  18 à 29 ans   0.551922
# 1   2016  30 à 44 ans   0.320626
# 2   2016  45 à 59 ans   0.127452
# 3   2017  18 à 29 ans   0.540514
# 4   2017  30 à 44 ans   0.328641

# %%
# Visualise the data into a graph
fig, ax = plt.subplots(figsize=(8,5))

for age in ages_ordre:
    df_plot = df_age_time[df_age_time["Age"] == age]

    ax.plot(
        df_plot["Année"],
        df_plot["Proportion"],
        marker="o",
        label=age
    )

ax.set_title("Évolution de la structure par âge toutes infractions confondues (2016–2024)")
ax.set_xlabel("Année")
ax.set_ylabel("Part des MEC")
ax.legend(title="Tranche d'âge")
ax.set_ylim(0, 1)

plt.tight_layout()
plt.show()
